# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Notes:
# 1. Performance of each team<br>
# 2. Impact of winning toss

# %% [markdown]
# ## Showcase performance of each team
# Columns needed:<br>
# 1. Season<br>
# 2. Team Name<br>
# 3. Number of wins per season

# %%
df=pd.read_csv("all_season_summary.csv")

# %%
df.head()
# Out:
#    season       id                                         name  short_name  \
# 0    2022  1304047  Chennai Super Kings v Kolkata Knight Riders   CSK v KKR
# 1    2022  1304048              Delhi Capitals v Mumbai Indians     DC v MI
# 2    2022  1304049   Punjab Kings v Royal Challengers Bangalore  PBKS v RCB
# 3    2022  1304050        Gujarat Titans v Lucknow Super Giants    GT v LSG
# 4    2022  1304051       Sunrisers Hyderabad v Rajasthan Royals    SRH v RR
#
#                                          description home_team away_team  \
# 0  1st Match (N), Indian Premier League at Mumbai...       CSK       KKR
# 1  2nd Match (D/N), Indian Premier League at Mumb...        DC        MI
# 2  3rd Match (N), Indian Premier League at Navi M...      PBKS       RCB
# 3  4th Match (N), Indian Premier League at Mumbai...        GT       LSG
# 4  5th Match (N), Indian Premier League at Pune, ...       SRH        RR
#
#   toss_won    decision 1st_inning_score  ...  \
# ...

# %%
df.drop(df[(df["home_team"]=="RPS") | (df["away_team"]=="RPS")].index,axis=0,inplace=True)
df.drop(df[(df["home_team"]=="GL") | (df["away_team"]=="GL")].index,axis=0,inplace=True)
df.drop(df[(df["home_team"]=="Kochi") | (df["away_team"]=="Kochi")].index,axis=0,inplace=True)
df.drop(df[(df["home_team"]=="PWI") | (df["away_team"]=="PWI")].index,axis=0,inplace=True)
df=df.apply(lambda x: x.replace("KXIP","PBKS"))

# %%
df.drop(df[(df["home_team"]=="GT") | (df["home_team"]=="LSG")].index,axis=0,inplace=True)
df.drop(df[(df["away_team"]=="GT") | (df["away_team"]=="LSG")].index,axis=0,inplace=True)

# %%
df.drop(df[(df["home_team"]=="GT") | (df["home_team"]=="LSG")].index,axis=0,inplace=True)
df.drop(df[(df["away_team"]=="GT") | (df["away_team"]=="LSG")].index,axis=0,inplace=True)

# %%
df1=pd.DataFrame(df.groupby(["season"],as_index=False)["winner"].value_counts())

# %%
def visualization(team):
    temp=df1[df1["winner"]==team]
    seasons_list=list(temp["season"].unique())
    plt.figure(dpi=200,figsize=(12,6))
    sns.scatterplot(x=temp["season"],y=temp["count"])
    p=sns.lineplot(x=temp["season"],y=temp["count"],linewidth=2,color='black')
    p.set_xticks(range(min(seasons_list), max(seasons_list)+1));
    plt.xticks(rotation=90);
    plt.xlabel('Season');
    plt.ylabel('Number Of Wins');

# %% [markdown]
# Visualization and Prediction <br>
#
# 1.Batsman name <br>
# 2.runs<br>
# 3.strike rate <br>
# 4.
